# %% [markdown]
# # **Part 1 - Create a data frame as mentioned below**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_data = {'first_name': ['Jason', np.nan, 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', np.nan, 'Ali', 'Milner', 'Cooze'], 
        'age': [42, np.nan, 36, 24, 73], 
        'sex': ['m', np.nan, 'f', 'm', 'f'], 
        'preTestScore': [4, np.nan, np.nan, 2, 3],
        'postTestScore': [25, np.nan, np.nan, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'sex', 'preTestScore', 'postTestScore'])
df
# Out:
#   first_name last_name   age  sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0    m           4.0           25.0
# 1        NaN       NaN   NaN  NaN           NaN            NaN
# 2       Tina       Ali  36.0    f           NaN            NaN
# 3       Jake    Milner  24.0    m           2.0           62.0
# 4        Amy     Cooze  73.0    f           3.0           70.0

# %% [markdown]
# **Drop the row, if any data contains “NaN” and Drop the row, where all the cells have “NaN”.**

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# **Create a new column called “location” with all missing values.**

# %%
df["Location"]=np.nan

# %%
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore  Location
# 0      Jason    Miller  42.0   m           4.0           25.0       NaN
# 3       Jake    Milner  24.0   m           2.0           62.0       NaN
# 4        Amy     Cooze  73.0   f           3.0           70.0       NaN

# %% [markdown]
# **Drop column if they contains only a missing values**

# %%
df.dropna(axis=1,inplace=True)
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# **Drop the rows that contain less than four observations**

# %%
df.loc[5]=np.nan
df
#adding a completely empty row to check the code below
# Out:
#   first_name last_name   age  sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0    m           4.0           25.0
# 3       Jake    Milner  24.0    m           2.0           62.0
# 4        Amy     Cooze  73.0    f           3.0           70.0
# 5        NaN       NaN   NaN  NaN           NaN            NaN

# %%
df.dropna(axis=0,thresh=4,inplace=True)
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
#  **Fill all the data with missing values of “ZERO”.**

# %%
df.loc[5]=np.nan
df
#adding a completely empty row to check the code below
# Out:
#   first_name last_name   age  sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0    m           4.0           25.0
# 3       Jake    Milner  24.0    m           2.0           62.0
# 4        Amy     Cooze  73.0    f           3.0           70.0
# 5        NaN       NaN   NaN  NaN           NaN            NaN

# %%
df = df.fillna(0)
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0
# 5          0         0   0.0   0           0.0            0.0

# %% [markdown]
# **Select rows ignoring missing data points in 'age' and 'sex'**

# %%
df = df[(df['age'] != 0) & (df['sex'] != 0)]

# %%
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# **As we can see the above code ignored row 5 which has zero values in age and sex**

# %% [markdown]
# # **Part 2**

# %%
#Reading Data.csv File and displaying it
dataSet=pd.read_csv("Data.csv")
dataSet
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
x = dataSet.iloc[:,:-1].values
print(x)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]

# %%
y= dataSet.iloc[:,:3].values
print(y)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]

# %% [markdown]
#  X goes from the reverse side of the columns and stops at length minus one (4-1) = 3

# %% [markdown]
# Y goes from the forward side of the columns and stops at 3 which is the same as x, hence x=y

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')
imputer.fit(dataSet[['Age', 'Salary']])
# Out:
# SimpleImputer()

# %%
dataSet[['Age', 'Salary']] = imputer.transform(dataSet[['Age', 'Salary']])

# %%
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# As we can see the NaN values are replaced by the imputer fucntion, and has replaced the NaN values in 4 and 6 with the mean of the rest of the data. This is a way to remove data discrepancies

# %% [markdown]
# # **Part 3**

# %%
from sklearn.datasets import load_boston
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 from sklearn.datasets import load_boston
#
# File ~\anaconda3\lib\site-packages\sklearn\datasets\__init__.py:156, in __getattr__(name)
#     105 if name == "load_boston":
#     106     msg = textwrap.dedent(
#     107         """
#     108         `load_boston` has been removed from scikit-learn since version 1.2.
#    (...)
#     154         """
#     155     )
# --> 156     raise ImportError(msg)
#     157 try:
#     158     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# non-invertible variable "B" assuming that racial self-segregation had a
# positive impact on house prices [2]. Furthermore the goal of the
# ...

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %% [markdown]
# Understand the data set using print (boston.DESCR)

# %%
#raw_df=boston
print(raw_df.describe())
# Out:
#                 0            1            2           3           4   \
# count  1012.000000  1012.000000  1012.000000  506.000000  506.000000
# mean    180.143778    12.008350    16.834792    0.069170    0.554695
# std     188.132839    17.250728     9.912616    0.253994    0.115878
# min       0.006320     0.000000     0.460000    0.000000    0.385000
# 25%       0.257830     0.000000     8.375000    0.000000    0.449000
# 50%      24.021000     7.240000    18.100000    0.000000    0.538000
# 75%     391.435000    16.780000    21.890000    0.000000    0.624000
# max     396.900000   100.000000    50.000000    1.000000    0.871000
#
#                5           6           7           8           9           10
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# ...

# %% [markdown]
# **Identify the type of “x” from the previous cell.**

# %%
x=data

# %%
type(x)
# Out:
# numpy.ndarray

# %% [markdown]
# **Create a data frame using the below code snippet.**

# %%
columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
#This is to properly create the dataframe. It has 13 columns and i got the headings from the internet
boston_df = pd.DataFrame(data, columns=columns)

# %%
boston_df.shape
# Out:
# (506, 13)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# # **Draw the box plot for the feature “DIS” and print the IQR for each column**

# %%
boston_df.boxplot(column="DIS")
print("IQR for each column:\n", boston_df.quantile(q=0.75) - boston_df.quantile(q=0.25))
plt.show()
# Out:
# IQR for each column:
#  CRIM         3.595038
# ZN          12.500000
# INDUS       12.910000
# CHAS         0.000000
# NOX          0.175000
# RM           0.738000
# AGE         49.050000
# DIS          3.088250
# RAD         20.000000
# TAX        387.000000
# PTRATIO      2.800000
# B           20.847500
# LSTAT       10.005000
# dtype: float64

# %% [markdown]
# # **Draw the plot to visualize the correalaiton between each feature.**

# %%
plt.matshow(boston_df.corr())
plt.xticks(range(len(columns)), columns, rotation=90)
plt.yticks(range(len(columns)), columns)
plt.colorbar()
plt.show()

# %% [markdown]
# # **Apply the histogram plot and find the inference out of it for the feature (PRICE)**

# %%
plt.hist(target, bins=50)
plt.xlabel("Price in $1000s")
plt.ylabel("Frequency")
plt.title("Distribution of House Prices")
plt.show()

# %% [markdown]
# # **Draw the scatter plot for the number of rooms Vs. value of house**

# %%
plt.scatter(boston_df["RM"], target)
plt.xlabel("Number of Rooms")
plt.ylabel("Value of House")
plt.show()
