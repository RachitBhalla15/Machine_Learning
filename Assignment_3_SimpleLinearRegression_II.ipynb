# %% [markdown]
# # Add necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the dataset

# %%
df=pd.read_csv('/content/delivery_time.csv')

# %% [markdown]
# # Describe the dataset and list first 10 rows

# %%
df.head(10)
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10
# 5          15.35             6
# 6          19.00             7
# 7           9.50             3
# 8          17.90            10
# 9          18.75             9

# %% [markdown]
# # Display the shape of the daatset

# %%
df.shape
# Out:
# (21, 2)

# %% [markdown]
# # Check any null values are there are not

# %%
df.isnull()
# Out:
#     Delivery Time  Sorting Time
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False         False
# 5           False         False
# 6           False         False
# 7           False         False
# 8           False         False
# 9           False         False
# 10          False         False
# 11          False         False
# 12          False         False
# 13          False         False
# 14          False         False
# 15          False         False
# 16          False         False
# 17          False         False
# 18          False         False
# 19          False         False
# 20          False         False

# %% [markdown]
# #Split the data into independent(y) and independent (x) variables and check the shape of the data ( X and Y)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
print(x.shape)
# Out:
# (21, 1)

# %%
print(y.shape)
# Out:
# (21,)

# %% [markdown]
# #Draw the scatter plot for Delivery Time Vs Sorting Time

# %%
plt.scatter(df['Delivery Time'], df['Sorting Time'])
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# # Draw the Box plot for "Delivery Time" and identify any outliers are there

# %%
sns.boxplot(df['Delivery Time'])
# Out:
# <Axes: >

# %% [markdown]
# # Draw the Box plot for "Delivery Time"  and " Sorting Time" in the same image/plot and identify any outliers are there

# %%
sns.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0900af59c0>,
#   <matplotlib.lines.Line2D at 0x7f0900af60b0>,
#   <matplotlib.lines.Line2D at 0x7f0900af6a40>,
#   <matplotlib.lines.Line2D at 0x7f0900af4100>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0900af73d0>,
#   <matplotlib.lines.Line2D at 0x7f0900af6f50>,
#   <matplotlib.lines.Line2D at 0x7f0900af4f10>,
#   <matplotlib.lines.Line2D at 0x7f0900af7a60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0900af6860>,
#   <matplotlib.lines.Line2D at 0x7f0900af65f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0900af6da0>,
#   <matplotlib.lines.Line2D at 0x7f0900af6e30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0900af5030>,
#   <matplotlib.lines.Line2D at 0x7f0900af7190>],
#  'means': []}

# %% [markdown]
# # Darw the historam for "Delivery Time"

# %% [markdown]
# # Display the correlation between Deliver Time and Sorting Time

# %% [markdown]
# # Split the data into Train and test with 70/30

# %% [markdown]
# # Build the model

# %% [markdown]
# # Display the regression coefficient values

# %% [markdown]
# #Predict the values

# %% [markdown]
# # Display the metrics

# %% [markdown]
# # Display the Root Mean Square Error of all three model and visualize the same
